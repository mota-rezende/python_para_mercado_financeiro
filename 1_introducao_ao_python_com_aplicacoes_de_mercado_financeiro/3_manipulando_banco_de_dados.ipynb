# %% [markdown]
# ## 1. Manipulando Banco de Dados

# %%
caminho = os.getcwd()

# %%
caminho
# Out:
# 'C:\\Users\\Lucas\\Documents\\Python\\python_para_mercado_financeiro'

# %%
type(caminho)
# Out:
# str

# %%
novo_caminho = 'C:\\Users\\Lucas\\Documents\\Python\\python_para_mercado_financeiro'

# %%
os.chdir(novo_caminho)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lucas\\Documents\\Python\\python_para_mercado_financeiro'

# %%
import pandas as pd

# %%
weg = pd.read_csv('WEGE3.SA.csv')

# %%
weg.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2022-07-11  26.889999  26.950001  26.370001  26.580000  26.140469  6136000
# 1  2022-07-12  26.530001  26.870001  26.370001  26.590000  26.150305  5197000
# 2  2022-07-13  26.330000  27.090000  25.950001  26.730000  26.287989  7119900
# 3  2022-07-14  26.440001  26.830000  26.040001  26.400000  25.963442  6633600
# 4  2022-07-15  26.389999  26.790001  25.850000  26.549999  26.110964  6464800

# %%
weg.Close.plot();

# %% [markdown]
# ## 2. Como trazer arquivos de outras pastas

# %%
bovespa = pd.read_csv('C:\\Users\\Lucas\\Documents\\Python\\python_para_mercado_financeiro\\^BVSP.csv')

# %%
bovespa.head()
# Out:
#          Date      Open      High      Low    Close  Adj Close    Volume
# 0  2022-07-11  100282.0  100282.0  97854.0  98212.0    98212.0   8893400
# 1  2022-07-12   98212.0   98737.0  97253.0  98271.0    98271.0  12566300
# 2  2022-07-13   98258.0   98928.0  97403.0  97881.0    97881.0  12208100
# 3  2022-07-14   97879.0   97879.0  95431.0  96121.0    96121.0  12579000
# 4  2022-07-15   96119.0   96971.0  95267.0  96551.0    96551.0  11347600

# %% [markdown]
# ## 3. Trazendo dados externos

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
lren = yf.download('LREN3.SA', start = '2017-01-01', end = '2021-07-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
lren.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2017-01-02  18.775900  19.013674  18.702108  18.972677  16.774588   676417
# 2017-01-03  19.103865  19.677799  18.808697  19.554813  17.289280  2976064
# 2017-01-04  19.636805  19.833582  19.177654  19.382631  17.137051  2671030
# 2017-01-05  19.464622  19.587610  19.161257  19.202253  16.977564  3587596
# 2017-01-06  19.202253  19.202253  18.808697  18.980877  16.781836  2139141

# %%
lren.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 4. Realizando um join

# %%
from IPython.display import Image
Image(url = 'https://www.thecrazyprogrammer.com/wp-content/uploads/2019/05/Joins-in-SQL-Inner-Outer-Left-and-Right-Join.jpg')
# Out:
# <img src="https://www.thecrazyprogrammer.com/wp-content/uploads/2019/05/Joins-in-SQL-Inner-Outer-Left-and-Right-Join.jpg"/>

# %%
lren.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2017-01-02  18.775900  19.013674  18.702108  18.972677  16.774588   676417
# 2017-01-03  19.103865  19.677799  18.808697  19.554813  17.289280  2976064
# 2017-01-04  19.636805  19.833582  19.177654  19.382631  17.137051  2671030
# 2017-01-05  19.464622  19.587610  19.161257  19.202253  16.977564  3587596
# 2017-01-06  19.202253  19.202253  18.808697  18.980877  16.781836  2139141

# %%
weg.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2022-07-11  26.889999  26.950001  26.370001  26.580000  26.140469  6136000
# 1  2022-07-12  26.530001  26.870001  26.370001  26.590000  26.150305  5197000
# 2  2022-07-13  26.330000  27.090000  25.950001  26.730000  26.287989  7119900
# 3  2022-07-14  26.440001  26.830000  26.040001  26.400000  25.963442  6633600
# 4  2022-07-15  26.389999  26.790001  25.850000  26.549999  26.110964  6464800

# %%
lren.rename(columns = {'Adj Close': 'LREN3'}, inplace = True)

# %%
lren.head()
# Out:
#                  Open       High        Low      Close      LREN3   Volume
# Date
# 2017-01-02  18.775900  19.013674  18.702108  18.972677  16.774588   676417
# 2017-01-03  19.103865  19.677799  18.808697  19.554813  17.289280  2976064
# 2017-01-04  19.636805  19.833582  19.177654  19.382631  17.137051  2671030
# 2017-01-05  19.464622  19.587610  19.161257  19.202253  16.977564  3587596
# 2017-01-06  19.202253  19.202253  18.808697  18.980877  16.781836  2139141

# %%
weg.rename(columns = {'Adj Close': 'WEGE3'}, inplace = True)

# %%
weg.head()
# Out:
#          Date       Open       High        Low      Close      WEGE3   Volume
# 0  2022-07-11  26.889999  26.950001  26.370001  26.580000  26.140469  6136000
# 1  2022-07-12  26.530001  26.870001  26.370001  26.590000  26.150305  5197000
# 2  2022-07-13  26.330000  27.090000  25.950001  26.730000  26.287989  7119900
# 3  2022-07-14  26.440001  26.830000  26.040001  26.400000  25.963442  6633600
# 4  2022-07-15  26.389999  26.790001  25.850000  26.549999  26.110964  6464800

# %%
novo_df = pd.merge(lren, weg, how = 'inner', on = 'Date')

# %%
weg['Date'] = pd.to_datetime(weg['Date'], format = '%Y-%m-%d')

# %%
weg.head()
# Out:
#         Date       Open       High        Low      Close      WEGE3   Volume
# 0 2022-07-11  26.889999  26.950001  26.370001  26.580000  26.140469  6136000
# 1 2022-07-12  26.530001  26.870001  26.370001  26.590000  26.150305  5197000
# 2 2022-07-13  26.330000  27.090000  25.950001  26.730000  26.287989  7119900
# 3 2022-07-14  26.440001  26.830000  26.040001  26.400000  25.963442  6633600
# 4 2022-07-15  26.389999  26.790001  25.850000  26.549999  26.110964  6464800

# %%
weg.index = weg['Date']

# %%
weg.head()
# Out:
#                  Date       Open       High        Low      Close      WEGE3  \
# Date
# 2022-07-11 2022-07-11  26.889999  26.950001  26.370001  26.580000  26.140469
# 2022-07-12 2022-07-12  26.530001  26.870001  26.370001  26.590000  26.150305
# 2022-07-13 2022-07-13  26.330000  27.090000  25.950001  26.730000  26.287989
# 2022-07-14 2022-07-14  26.440001  26.830000  26.040001  26.400000  25.963442
# 2022-07-15 2022-07-15  26.389999  26.790001  25.850000  26.549999  26.110964
#
#              Volume
# Date
# 2022-07-11  6136000
# 2022-07-12  5197000
# 2022-07-13  7119900
# 2022-07-14  6633600
# 2022-07-15  6464800

# %%
weg.drop(['Date'], axis = 1, inplace = True)

# %%
weg.head()
# Out:
#                  Open       High        Low      Close      WEGE3   Volume
# Date
# 2022-07-11  26.889999  26.950001  26.370001  26.580000  26.140469  6136000
# 2022-07-12  26.530001  26.870001  26.370001  26.590000  26.150305  5197000
# 2022-07-13  26.330000  27.090000  25.950001  26.730000  26.287989  7119900
# 2022-07-14  26.440001  26.830000  26.040001  26.400000  25.963442  6633600
# 2022-07-15  26.389999  26.790001  25.850000  26.549999  26.110964  6464800

# %%
weg = yf.download('WEGE3.SA', start = '2017-01-01', end = '2021-07-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
weg.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2017-01-02  5.923076  5.926923  5.734615  5.807692   5.265739  2133040
# 2017-01-03  5.861538  6.130769  5.842307  6.100000   5.530771  5048160
# 2017-01-04  6.107692  6.126923  5.915384  5.953846   5.398255  5267860
# 2017-01-05  5.965384  6.034615  5.876923  5.938461   5.384305  4526340
# 2017-01-06  5.980769  6.050000  5.907692  5.988461   5.429639  3394560

# %%
novo_df = pd.merge(lren, weg, how = 'inner', on = 'Date')

# %%
novo_df.head()
# Out:
#                Open_x     High_x      Low_x    Close_x      LREN3  Volume_x  \
# Date
# 2017-01-02  18.775900  19.013674  18.702108  18.972677  16.774588    676417
# 2017-01-03  19.103865  19.677799  18.808697  19.554813  17.289280   2976064
# 2017-01-04  19.636805  19.833582  19.177654  19.382631  17.137051   2671030
# 2017-01-05  19.464622  19.587610  19.161257  19.202253  16.977564   3587596
# 2017-01-06  19.202253  19.202253  18.808697  18.980877  16.781836   2139141
#
#               Open_y    High_y     Low_y   Close_y     WEGE3  Volume_y
# Date
# 2017-01-02  5.923076  5.926923  5.734615  5.807692  5.265739   2133040
# 2017-01-03  5.861538  6.130769  5.842307  6.100000  5.530771   5048160
# 2017-01-04  6.107692  6.126923  5.915384  5.953846  5.398255   5267860
# 2017-01-05  5.965384  6.034615  5.876923  5.938461  5.384305   4526340
# 2017-01-06  5.980769  6.050000  5.907692  5.988461  5.429639   3394560

# %%
cotacoes = novo_df[['LREN3' , 'WEGE3']]

# %%
weg.rename(columns = {'Adj Close': 'WEGE3'}, inplace = True)

# %%
cotacoes.plot();

# %%
cotacoes.head()
# Out:
#                 LREN3     WEGE3
# Date
# 2017-01-02  16.774588  5.265739
# 2017-01-03  17.289280  5.530771
# 2017-01-04  17.137051  5.398255
# 2017-01-05  16.977564  5.384305
# 2017-01-06  16.781836  5.429639

# %% [markdown]
# ## 5. Análise de dados

# %%
# !pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 93.5 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sv

# %%
relatorio = sv.analyze(cotacoes)
# Out:
# /usr/local/lib/python3.10/dist-packages/sweetviz/dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# /usr/local/lib/python3.10/dist-packages/sweetviz/dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
#                                              |          | [  0%]   00:00 -> (? left)
# /usr/local/lib/python3.10/dist-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# ...

# %%
relatorio.show_html('Relatorio_WEGE3_LREN4.html')
# Out:
# Report Relatorio_WEGE3_LREN4.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
cotacoes.WEGE3.hist()
# Out:
# <Axes: >

# %%
cotacoes.LREN3.hist()
# Out:
# <Axes: >
